# %%
import os
import shutil
import statistics

# %%
def process_video_performances(base_path):
    """
    Process video and performance files to create new directories with unique videos and scores.
    
    Args:
    base_path (str): Path to the directory containing 'videos' and 'performance' subdirectories
    """
    # Paths to input and output directories
    videos_dir = os.path.join(base_path, 'videos')
    performance_dir = os.path.join(base_path, 'performance')
    
    # Create new directories for unique content
    unique_videos_dir = os.path.join(base_path, 'unique_videos')
    unique_performance_dir = os.path.join(base_path, 'unique_performances')
    
    # Create output directories if they don't exist
    os.makedirs(unique_videos_dir, exist_ok=True)
    os.makedirs(unique_performance_dir, exist_ok=True)
    
    # Validate input directories exist
    if not os.path.exists(videos_dir) or not os.path.exists(performance_dir):
        raise ValueError("Both 'videos' and 'performance' directories must exist in the base path.")
    
    # Collect video and performance files
    video_files = os.listdir(videos_dir)
    performance_files = os.listdir(performance_dir)
    
    # Dictionary to store performance scores for each unique video
    video_performances = {}
    
    # Collect performance scores
    for perf_file in performance_files:
        # Extract video name (assuming performance files have same name as video files)
        video_name = perf_file
        
        # Read performance file
        try:
            with open(os.path.join(performance_dir, perf_file), 'r') as f:
                score = float(f.read().strip())
        except (ValueError, FileNotFoundError) as e:
            print(f"Skipping {perf_file} due to error: {e}")
            continue
        
        # Accumulate scores for each unique video
        if video_name not in video_performances:
            video_performances[video_name] = {
                'scores': [],
                'video_path': None
            }
        video_performances[video_name]['scores'].append(score)
        
        # Find corresponding video file
        if video_name in video_files:
            video_performances[video_name]['video_path'] = os.path.join(videos_dir, video_name)
    
    # Process unique videos with averaged scores
    for video_name, data in video_performances.items():
        # Skip if no video file found
        if not data['video_path']:
            print(f"No video file found for {video_name}")
            continue
        
        # Calculate average score
        avg_score = round(statistics.mean(data['scores']), 2)
        
        # Copy unique video to new directory
        unique_video_path = os.path.join(unique_videos_dir, video_name)
        shutil.copy2(data['video_path'], unique_video_path)
        
        # Write average score to new performance file
        unique_performance_path = os.path.join(unique_performance_dir, video_name)
        with open(unique_performance_path, 'w') as f:
            f.write(str(avg_score))
        
        print(f"Processed {video_name}: Average score = {avg_score}")
    
    print("Video performance processing complete.")
    print(f"Unique videos saved to: {unique_videos_dir}")
    print(f"Unique performance scores saved to: {unique_performance_dir}")

def main():
    # Use current directory as base path
    base_path = os.getcwd()
    process_video_performances(base_path)

if __name__ == "__main__":
    main()
# Out:
# No video file found for hd-617288786873081.txt
# No video file found for hd-895042408159688.txt
# No video file found for hd-1119272995406354.txt
# No video file found for hd-789793989900194.txt
# No video file found for hd-963303392509872.txt
# No video file found for hd-6174004652651971.txt
# No video file found for hd-678133704039459.txt
# No video file found for hd-1698824364241828.txt
# No video file found for hd-874747697073121.txt
# No video file found for hd-1689212771862832.txt
# No video file found for hd-613417017284998.txt
# No video file found for hd-991636695150147.txt
# No video file found for hd-898402801287469.txt
# No video file found for hd-888593019388197.txt
# No video file found for hd-874084244131796.txt
# No video file found for hd-680540137074841.txt
# No video file found for hd-958675741960412.txt
# No video file found for hd-992418235673669.txt
# No video file found for hd-883738210384679.txt
# No video file found for hd-881925359723909.txt
# No video file found for hd-871075730546911.txt
# No video file found for hd-9020567984620018.txt
# No video file found for hd-808097524590260.txt
# No video file found for hd-872760463806517.txt
# No video file found for hd-988185795921355.txt
# No video file found for hd-894559812351386.txt
# No video file found for hd-965108935263649.txt
# No video file found for hd-618555366744628.txt
# No video file found for hd-924865635226814.txt
# No video file found for hd-937410954343974.txt
# No video file found for hd-899987727789409.txt
# No video file found for hd-877511836784655.txt
# No video file found for hd-8715627171842855.txt
# No video file found for hd-1693566687752051.txt
# No video file found for hd-932296771464171.txt
# No video file found for hd-797024995612413.txt
# No video file found for hd-882019143545185.txt
# No video file found for hd-989600295478567.txt
# No video file found for hd-905545323817883.txt
# No video file found for hd-803897110603133.txt
# No video file found for hd-942779243913664.txt
# No video file found for hd-894457734962164.txt
# No video file found for hd-933913194646448.txt
# No video file found for hd-695130362192250.txt
# No video file found for hd-877129693575192.txt
# No video file found for hd-989930303148492.txt
# No video file found for hd-893173505441981.txt
# No video file found for hd-817763467176157.txt
# No video file found for hd-885209946993560.txt
# No video file found for hd-876239523982490.txt
# No video file found for hd-621652523105267.txt
# No video file found for hd-958267042213267.txt
# No video file found for hd-930116227971248.txt
# No video file found for hd-6764280623620361.txt
# No video file found for hd-891661008828094.txt
# No video file found for hd-911482386703699.txt
# No video file found for hd-691581235967071.txt
# No video file found for hd-690670309134450.txt
# No video file found for hd-989969399547901.txt
# No video file found for hd-924585008982148.txt
# No video file found for hd-891684945300160.txt
# No video file found for hd-874543520932484.txt
# No video file found for hd-620154813059921.txt
# No video file found for hd-613152173490344.txt
# No video file found for hd-874190910572544.txt
# No video file found for hd-889728479746704.txt
# No video file found for hd-877210454387561.txt
# No video file found for hd-689771035910864.txt
# No video file found for hd-954440782897187.txt
# No video file found for hd-903913985069116.txt
# No video file found for hd-691252805779835.txt
# No video file found for hd-896589688256009.txt
# No video file found for hd-817475239730695.txt
# No video file found for hd-620702145697389.txt
# No video file found for hd-424394867097391.txt
# No video file found for hd-879049300656635.txt
# No video file found for hd-693988272279384.txt
# No video file found for hd-907416560296782.txt
# No video file found for hd-909110383822260.txt
# No video file found for hd-8995485367146316.txt
# No video file found for hd-902456848100089.txt
# No video file found for hd-958774641659407.txt
# No video file found for hd-817768845898837.txt
# No video file found for hd-6107397609317402.txt
# No video file found for hd-815391233916449.txt
# No video file found for hd-987232088920289.txt
# No video file found for hd-903960640750545.txt
# No video file found for hd-967731231014052.txt
# No video file found for hd-817477363934899.txt
# No video file found for hd-796944101940903.txt
# No video file found for hd-691857912087615.txt
# No video file found for hd-880568190186256.txt
# No video file found for hd-606237444463640.txt
# No video file found for hd-682791943270614.txt
# No video file found for hd-932038864470963.txt
# No video file found for hd-951491629353387.txt
# No video file found for hd-883246492824014.txt
# No video file found for hd-8008073409211713.txt
# No video file found for hd-793257836073148.txt
# No video file found for hd-888183703182855.txt
# No video file found for hd-905844110841635.txt
# No video file found for hd-925596815118953.txt
# No video file found for hd-8816515918390519.txt
# No video file found for hd-429145826826558.txt
# No video file found for hd-613197413789434.txt
# No video file found for hd-910958533691058.txt
# No video file found for hd-909937876815529.txt
# No video file found for hd-897088088160051.txt
# No video file found for hd-902843234362370.txt
# No video file found for hd-687024156350870.txt
# No video file found for hd-8796411607036992.txt
# No video file found for hd-937508703912579.txt
# No video file found for hd-898103501380741.txt
# No video file found for hd-621266003076530.txt
# No video file found for hd-8828692983838031.txt
# No video file found for hd-873560550525047.txt
# No video file found for hd-611188517518682.txt
# No video file found for hd-992064161877405.txt
# No video file found for hd-8806609246079208.txt
# No video file found for hd-944160410298140.txt
# No video file found for hd-688887926060399.txt
# No video file found for hd-929300948587514.txt
# No video file found for hd-676770877464110.txt
# No video file found for hd-791572172961239.txt
# No video file found for hd-612555930635832.txt
# No video file found for hd-929511878466995.txt
# No video file found for hd-983335896508749.txt
# No video file found for hd-889375178765113.txt
# No video file found for hd-888062106715252.txt
# No video file found for hd-966458824582483.txt
# No video file found for hd-603099807587246.txt
# No video file found for hd-935530867630269.txt
# No video file found for hd-932703258597949.txt
# No video file found for hd-871286287458461.txt
# No video file found for hd-684264882912286.txt
# No video file found for hd-911172609864769.txt
# No video file found for hd-686083626588321.txt
# No video file found for hd-939795907980426.txt
# No video file found for hd-877662697022279.txt
# No video file found for hd-879631723735807.txt
# No video file found for hd-987643572956494.txt
# No video file found for hd-966019214364727.txt
# No video file found for hd-901272811190482.txt
# No video file found for hd-809480737932683.txt
# No video file found for hd-612426467555072.txt
# No video file found for hd-966715248087290.txt
# No video file found for hd-8100667816697710.txt
# No video file found for hd-903060767715541.txt
# No video file found for hd-872222594086011.txt
# No video file found for hd-999607261342550.txt
# No video file found for hd-898967424867870.txt
# No video file found for hd-944981830978756.txt
# No video file found for hd-696006115320413.txt
# No video file found for hd-986360206629277.txt
# No video file found for hd-938232524809973.txt
# No video file found for hd-940634710428411.txt
# No video file found for hd-935558767885747.txt
# No video file found for hd-605272664726548.txt
# No video file found for hd-892383375224287.txt
# No video file found for hd-817135236672734.txt
# No video file found for hd-960884234555681.txt
# No video file found for hd-944755280756437.txt
# No video file found for hd-790055392972248.txt
# No video file found for hd-814072014151046.txt
# No video file found for hd-890166872024685.txt
# No video file found for hd-6172742522782221.txt
# No video file found for hd-425151876539382.txt
# No video file found for hd-818776323774715.txt
# No video file found for hd-818462803696191.txt
# No video file found for hd-942524046763053.txt
# No video file found for hd-885670366433640.txt
# No video file found for hd-901695498551491.txt
# No video file found for hd-680549530054789.txt
# No video file found for hd-933773150951550.txt
# No video file found for hd-1118763132933218.txt
# No video file found for hd-888056015719840.txt
# No video file found for hd-880340126836307.txt
# No video file found for hd-424802420355057.txt
# No video file found for hd-679261516829908.txt
# No video file found for hd-671839840899900.txt
# No video file found for hd-689599909618915.txt
# No video file found for hd-682596103528135.txt
# No video file found for hd-686488653080244.txt
# Video performance processing complete.
# Unique videos saved to: /home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Trial/unique_videos
# Unique performance scores saved to: /home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Trial/unique_performances
