# %%
import os
import shutil
import cv2
import numpy as np
import statistics

# %%
def get_video_hash(video_path, num_frames=10):
    """
    Generate a perceptual hash of the video by sampling frames.
    
    Args:
    video_path (str): Path to the video file
    num_frames (int): Number of frames to sample for hashing
    
    Returns:
    str: Perceptual hash of the video
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        return None
    
    # Get total number of frames
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    # Sample frames evenly across the video
    frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    
    # Collect sampled frames
    sampled_frames = []
    for idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if ret:
            # Convert to grayscale and resize
            gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            resized_frame = cv2.resize(gray_frame, (8, 8), interpolation=cv2.INTER_AREA)
            
            # Compute the mean of the frame
            avg = np.mean(resized_frame)
            
            # Create binary fingerprint based on comparison to mean
            binary_frame = (resized_frame > avg).astype(int)
            
            sampled_frames.append(binary_frame.tobytes())
    
    cap.release()
    
    # Generate a hash based on sampled frames
    return hash(tuple(sampled_frames))

def find_unique_videos(videos_dir, performance_dir):
    # Collect all video files
    video_files = [f for f in os.listdir(videos_dir) if f.lower().endswith(('.mp4', '.avi', '.mov'))]
    
    # Dictionary to track unique videos
    unique_videos = {}
    
    # Compute hashes and collect performance scores
    for video_file in video_files:
        video_path = os.path.join(videos_dir, video_file)
        video_hash = get_video_hash(video_path)
        
        # Try to read performance score
        try:
            with open(os.path.join(performance_dir, video_file), 'r') as f:
                score = float(f.read().strip())
        except (FileNotFoundError, ValueError):
            print(f"No performance score found for {video_file}")
            continue
        
        # Track unique videos and their performances
        if video_hash not in unique_videos:
            unique_videos[video_hash] = {
                'files': [video_file],
                'performances': [score]
            }
        else:
            unique_videos[video_hash]['files'].append(video_file)
            unique_videos[video_hash]['performances'].append(score)
    
    return unique_videos

def process_unique_videos(base_path):
    # Define input and output directories
    videos_dir = os.path.join(base_path, 'videos')
    performance_dir = os.path.join(base_path, 'performance')
    
    # Create output directories
    unique_videos_dir = os.path.join(base_path, 'unique_videos')
    unique_performance_dir = os.path.join(base_path, 'unique_performances')
    os.makedirs(unique_videos_dir, exist_ok=True)
    os.makedirs(unique_performance_dir, exist_ok=True)
    
    # Find unique videos
    unique_videos = find_unique_videos(videos_dir, performance_dir)
    
    # Process unique videos
    for video_hash, video_data in unique_videos.items():
        # Choose first file as representative
        representative_file = video_data['files'][0]
        
        # Calculate average performance
        avg_performance = round(statistics.mean(video_data['performances']), 2)
        
        # Copy unique video to unique_videos directory
        src_video_path = os.path.join(videos_dir, representative_file)
        dst_video_path = os.path.join(unique_videos_dir, representative_file)
        shutil.copy2(src_video_path, dst_video_path)
        
        # Write average performance to unique_performances directory
        performance_path = os.path.join(unique_performance_dir, representative_file)
        with open(performance_path, 'w') as f:
            f.write(str(avg_performance))
        
        # Print information about unique video
        print(f"Unique Video: {representative_file}")
        print(f"  Duplicate files: {video_data['files']}")
        print(f"  Average Performance: {avg_performance}")
        print("---")

def main():
    # Use current directory as base path
    base_path = os.getcwd()
    process_unique_videos(base_path)
    print("Unique video processing complete.")

if __name__ == "__main__":
    main()

# %%
import os
import cv2
import numpy as np
import hashlib
from pathlib import Path
from collections import defaultdict

# Define paths
BASE_PATH = os.getcwd()
VIDEOS_FOLDER = BASE_PATH + "/videos"
PERFORMANCE_FOLDER = BASE_PATH + "/performance"
UNIQUE_VIDEOS_FOLDER = BASE_PATH + "/unique_videos"
UNIQUE_PERFORMANCE_FOLDER = BASE_PATH + "/unique_performances"

# Create output folders if they don't exist
os.makedirs(UNIQUE_VIDEOS_FOLDER, exist_ok=True)
os.makedirs(UNIQUE_PERFORMANCE_FOLDER, exist_ok=True)

# Helper function to compute hash for frames
def compute_video_hash(video_path):
    cap = cv2.VideoCapture(video_path)
    hasher = hashlib.md5()  # Hash function
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        # Resize frame for consistent hashing
        resized_frame = cv2.resize(frame, (256, 256), interpolation=cv2.INTER_AREA)
        hasher.update(resized_frame.tobytes())
    cap.release()
    return hasher.hexdigest()

# Map to store video hash and performance scores
video_hash_map = defaultdict(list)  # {hash: [(video_path, score)]}

# Process videos and performance files
for video_file in os.listdir(VIDEOS_FOLDER):
    video_path = os.path.join(VIDEOS_FOLDER, video_file)
    performance_file = os.path.join(PERFORMANCE_FOLDER, f"{Path(video_file).stem}.txt")
    
    # Skip if performance file doesn't exist
    if not os.path.exists(performance_file):
        print(f"Performance file missing for {video_file}. Skipping...")
        continue
    
    # Read performance score
    with open(performance_file, "r") as pf:
        score = float(pf.read().strip())
    
    # Compute hash for the video
    video_hash = compute_video_hash(video_path)
    
    # Add to hash map
    video_hash_map[video_hash].append((video_path, score))

# Handle unique videos and performance scores
for video_hash, videos in video_hash_map.items():
    # If multiple videos share the same hash
    if len(videos) > 1:
        print(f"Duplicate videos found: {[v[0] for v in videos]}")
        # Take the first video and average performance scores
        first_video, _ = videos[0]
        avg_score = np.mean([score for _, score in videos])
        
        # Copy the video to unique_videos
        unique_video_path = os.path.join(UNIQUE_VIDEOS_FOLDER, Path(first_video).name)
        if not os.path.exists(unique_video_path):
            os.rename(first_video, unique_video_path)
        
        # Save average performance score
        unique_performance_path = os.path.join(UNIQUE_PERFORMANCE_FOLDER, f"{Path(first_video).stem}.txt")
        with open(unique_performance_path, "w") as upf:
            upf.write(f"{avg_score:.2f}")
    else:
        # Single video is unique
        video_path, score = videos[0]
        
        # Copy the video to unique_videos
        unique_video_path = os.path.join(UNIQUE_VIDEOS_FOLDER, Path(video_path).name)
        if not os.path.exists(unique_video_path):
            os.rename(video_path, unique_video_path)
        
        # Save performance score
        unique_performance_path = os.path.join(UNIQUE_PERFORMANCE_FOLDER, f"{Path(video_path).stem}.txt")
        with open(unique_performance_path, "w") as upf:
            upf.write(f"{score:.2f}")
# Out:
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-906909830682725', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-924585008982148', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-891661008828094', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-689363059404444', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-987232088920289', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-999607261342550', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-872222594086011', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-612555930635832', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-9020567984620018', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-958675741960412', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-874747697073121', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-871185627435460', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-909937876815529', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-872760463806517', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-894457734962164', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-877511836784655', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-786610583313461', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-978448136455993', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-925596815118953', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-687665956347322', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-613417017284998', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-890166872024685', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-989600295478567', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-897088088160051', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-680540137074841', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-687024156350870', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-896589688256009', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-885689066019680', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-872400620956045', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-988185795921355', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8806609246079208', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-991636695150147', '/home/vishist/coding/Startup_Assignm ...
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-888056015719840', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-621266003076530', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-911172609864769', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-605272664726548', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-6046690562050296', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-883246492824014', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-933773150951550', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8816515918390519', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-696006115320413', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-930116227971248', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-796944101940903', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-679261516829908', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-992064161877405', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-620154813059921', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-937410954343974', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-426644026275739', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8828692983838031', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-890005255637433', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-680549530054789', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-789715035654710', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-691252805779835', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-896598988012982', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-6172742522782221', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-688887926060399', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-933913194646448', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-897680994566577']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-606237444463640', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-889604775414234', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-872188860590219', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-613152173490344', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-889375178765113', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-690670309134450', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-693988272279384', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-910958533691058', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-896843165102015', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-1119272995406354', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-427878012859864', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-6096104653784047', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-813828049840959', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-871075730546911', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-817768845898837', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-682596103528135', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-618555366744628', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-695130362192250', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-691857912087615', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-899155277883965', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-871037203883530', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-899987727789409', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-891684945300160', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-898402801287469', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-958774641659407']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-904480964010630', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-932296771464171']

# %%
import os
import cv2
import numpy as np
import hashlib
from pathlib import Path
from collections import defaultdict
import shutil  # For copying files

# Define paths
BASE_PATH = os.getcwd()
VIDEOS_FOLDER = BASE_PATH + "/videos"
PERFORMANCE_FOLDER = BASE_PATH + "/performance"
UNIQUE_VIDEOS_FOLDER = BASE_PATH + "/unique_videos"
UNIQUE_PERFORMANCE_FOLDER = BASE_PATH + "/unique_performances"

# Create output folders if they don't exist
os.makedirs(UNIQUE_VIDEOS_FOLDER, exist_ok=True)
os.makedirs(UNIQUE_PERFORMANCE_FOLDER, exist_ok=True)

# Helper function to compute hash for frames
def compute_video_hash(video_path):
    cap = cv2.VideoCapture(video_path)
    hasher = hashlib.md5()  # Hash function
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        # Resize frame for consistent hashing
        resized_frame = cv2.resize(frame, (256, 256), interpolation=cv2.INTER_AREA)
        hasher.update(resized_frame.tobytes())
    cap.release()
    return hasher.hexdigest()

# Map to store video hash and performance scores
video_hash_map = defaultdict(list)  # {hash: [(video_path, score)]}

# Process videos and performance files
for video_file in os.listdir(VIDEOS_FOLDER):
    video_path = os.path.join(VIDEOS_FOLDER, video_file)
    performance_file = os.path.join(PERFORMANCE_FOLDER, f"{Path(video_file).stem}.txt")
    
    # Skip if performance file doesn't exist
    if not os.path.exists(performance_file):
        print(f"Performance file missing for {video_file}. Skipping...")
        continue
    
    # Read performance score
    with open(performance_file, "r") as pf:
        score = float(pf.read().strip())
    
    # Compute hash for the video
    video_hash = compute_video_hash(video_path)
    
    # Add to hash map
    video_hash_map[video_hash].append((video_path, score))

# Handle unique videos and performance scores
for video_hash, videos in video_hash_map.items():
    # If multiple videos share the same hash
    if len(videos) > 1:
        print(f"Duplicate videos found: {[v[0] for v in videos]}")
        # Take the first video and average performance scores
        first_video, _ = videos[0]
        avg_score = np.mean([score for _, score in videos])
        
        # Copy the video to unique_videos
        unique_video_path = os.path.join(UNIQUE_VIDEOS_FOLDER, Path(first_video).name)
        shutil.copy2(first_video, unique_video_path)
        
        # Save average performance score
        unique_performance_path = os.path.join(UNIQUE_PERFORMANCE_FOLDER, f"{Path(first_video).stem}.txt")
        with open(unique_performance_path, "w") as upf:
            upf.write(f"{avg_score:.2f}")
    else:
        # Single video is unique
        video_path, score = videos[0]
        
        # Copy the video to unique_videos
        unique_video_path = os.path.join(UNIQUE_VIDEOS_FOLDER, Path(video_path).name)
        shutil.copy2(video_path, unique_video_path)
        
        # Save performance score
        unique_performance_path = os.path.join(UNIQUE_PERFORMANCE_FOLDER, f"{Path(video_path).stem}.txt")
        with open(unique_performance_path, "w") as upf:
            upf.write(f"{score:.2f}")
# Out:
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-954832972830686', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-797024995612413']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-791572172961239', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-424802420355057', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8008073409211713', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-803990118540094']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-686083626588321', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-686488653080244', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-612426467555072', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-907416560296782', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-606237444463640', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-889604775414234', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-872188860590219', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-613152173490344', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-889375178765113', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-690670309134450', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-693988272279384', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-910958533691058', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-896843165102015', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-1119272995406354', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-427878012859864', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-6096104653784047', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-813828049840959', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-871075730546911', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-817768845898837', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-682596103528135', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-618555366744628', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-695130362192250', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-691857912087615', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-899155277883965', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-871037203883530', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-899987727789409', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-891684945300160', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-898402801287469', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-958774641659407']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-881270063889884', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-888183703182855']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-611188517518682', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-617288786873081', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-924865635226814', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-881925359723909', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-903960640750545']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-989284361966196', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-940634710428411', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-977008307250628', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-689599909618915', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-906909830682725', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-924585008982148', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-891661008828094', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-689363059404444', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-987232088920289', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-999607261342550', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-872222594086011', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-612555930635832', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-9020567984620018', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-958675741960412', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-874747697073121', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-871185627435460', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-909937876815529', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-872760463806517', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-894457734962164', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-877511836784655', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-786610583313461', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-978448136455993', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-925596815118953', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-687665956347322', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-613417017284998', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-890166872024685', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-989600295478567', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-897088088160051', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-680540137074841', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-687024156350870', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-896589688256009', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-885689066019680', '/home/vishist/coding/Startup_Assignme ...
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-886049645973007', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-903060767715541', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-684264882912286', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-689771035910864', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-888056015719840', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-621266003076530', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-911172609864769', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-605272664726548', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-6046690562050296', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-883246492824014', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-933773150951550', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8816515918390519', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-696006115320413', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-930116227971248', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-796944101940903', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-679261516829908', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-992064161877405', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-620154813059921', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-937410954343974', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-426644026275739', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8828692983838031', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-890005255637433', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-680549530054789', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-789715035654710', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-691252805779835', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-896598988012982', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-6172742522782221', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-688887926060399', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-933913194646448', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-897680994566577']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-881342303358042', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-874543520932484']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-876121221160846', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-873317140849832', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-932703258597949']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-1685108828975354', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-814072014151046']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-901272811190482', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-874190910572544', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-975523146942238', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-621652523105267', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-904480964010630', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-932296771464171']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-886609482926268', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-819765763526762', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-911926190614858', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-815391233916449', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-790055392972248']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-880340126836307', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-874084244131796', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-1689212771862832']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-889728479746704', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-893539262677484']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-929511878466995', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-816335920524988']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-891391212618023', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-879049300656635', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-987287402378278']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-802443478544141', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8057957437624799', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-811606650922029', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-817763467176157']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-789793989900194', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-880568190186256']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-925260332281638', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-909110383822260']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-818776323774715', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-818462803696191', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-808321904744283', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-885209946993560']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8995485367146316', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-424394867097391', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-997580728807604', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-1118763132933218']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-8796411607036992', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-986360206629277']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-887363366529815', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-817477363934899']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-989930303148492', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-817135236672734']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-987643572956494', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-808097524590260']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-807800198130528', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-989969399547901']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-905739711170399', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-894559522288371']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-888062106715252', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-965108935263649']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-929300948587514', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-797179088937277']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-904174908300812', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-963303392509872']
# Duplicate videos found: ['/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-1698824364241828', '/home/vishist/coding/Startup_Assignments/FuelGrowth/Influencer-Face-Metrics/Jupyter_notebooks/videos/hd-883738210384679']
